# %%
import torch

# %%
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
# Out:
# PyTorch version: 2.5.1+cu118
# CUDA available: True
# CUDA version: 11.8

# %%
if torch.cuda.is_available():
    print("Number of GPUs:", torch.cuda.device_count())
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Number of GPUs: 1
# GPU 0: NVIDIA GeForce RTX 2050

# %%
# Tentukan perangkat (device) yang akan digunakan
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Buat tensor dan pindahkan ke GPU
if torch.cuda.is_available():
    x = torch.randn(3, 3).to(device)
    print("Tensor on GPU:", x)
    y = x + 2
    print("Result of calculation on GPU:", y)
# Out:
# Using device: cuda
# Tensor on GPU: tensor([[-0.4774,  0.2006, -0.4698],
#         [ 0.6576,  1.1696, -0.5920],
#         [-0.5810,  0.0888, -2.0448]], device='cuda:0')
# Result of calculation on GPU: tensor([[ 1.5226,  2.2006,  1.5302],
#         [ 2.6576,  3.1696,  1.4080],
#         [ 1.4190,  2.0888, -0.0448]], device='cuda:0')

# %%
if torch.cuda.is_available():
    # Membuat tensor acak besar di GPU
    a = torch.randn(10000, 10000).cuda()
    b = torch.randn(10000, 10000).cuda()
    # Melakukan perkalian matriks
    c = torch.matmul(a, b)
    print("Matrix multiplication test passed on GPU")
# Out:
# Matrix multiplication test passed on GPU

# %%
import numpy as np

print("PyTorch version:", torch.__version__)
print("NumPy version:", np.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    # Tes operasi sederhana
    x = torch.randn(3,3).cuda()
    y = x + 1
    print("Tes GPU berhasil, hasil:", y[0,0].item())
# Out:
# PyTorch version: 2.5.1+cu118
# NumPy version: 2.4.4
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 2050
# Tes GPU berhasil, hasil: -0.622963547706604
